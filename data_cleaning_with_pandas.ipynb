# %% [markdown]
# # Step 1:
#        Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Step 2:
#        read(import ) csv file.

# %%
df=pd.read_csv("ml_dataset.csv.csv")
df
# Out:
#        CustomerID    JoinDate   Age  Gender        City         Segment  \
# 0               1  2022-04-17  21.0    Male   Islamabad     Home Office
# 1               2  2022-10-19  28.0    Male     Karachi     Home Office
# 2               3  2025-08-16  48.0   Other  Faisalabad  Small Business
# 3               4  2024-07-24  50.0  Female      Multan        Consumer
# 4               5  2025-07-14  58.0   Other    Peshawar  Small Business
# ...           ...         ...   ...     ...         ...             ...
# 10095        4700  2023-06-24  30.0    Male   Hyderabad       Corporate
# 10096        3058  2024-05-03  20.0    Male      Multan     Home Office
# 10097        1186  2022-01-25  42.0    Male      Multan        Consumer
# 10098        3208  2023-03-04  47.0  Female         NaN  Small Business
# 10099        9463  2024-08-08  25.0  Female      Multan        Consumer
#
#       ProductCategory    Income  YearsExperience  WebsiteVisits  ...  \
# ...

# %% [markdown]
# # step 3:head().
#       => view the first through head() function.
#       => when you want specific rows insert number in paranthesis.

# %%
df.head()
# Out:
#    CustomerID    JoinDate   Age  Gender        City         Segment  \
# 0           1  2022-04-17  21.0    Male   Islamabad     Home Office
# 1           2  2022-10-19  28.0    Male     Karachi     Home Office
# 2           3  2025-08-16  48.0   Other  Faisalabad  Small Business
# 3           4  2024-07-24  50.0  Female      Multan        Consumer
# 4           5  2025-07-14  58.0   Other    Peshawar  Small Business
#
#   ProductCategory    Income  YearsExperience  WebsiteVisits  ...  \
# 0          Sports   73359.0                0             56  ...
# 1         Grocery  117472.0                9            306  ...
# 2          Sports  111405.0               25            268  ...
# 3       Furniture  137462.0               30             43  ...
# 4       Furniture   31262.0               37            208  ...
#
#    AvgOrderValue  AnnualSpending  DiscountPercent  EmailOpens  TimeOnSiteMin  \
# 0        1407.71        56308.38             13.6          42           63.5
# ...

# %% [markdown]
# # step 4 : tail().
#             => tail() is function used to see the last rows.

# %%
df.tail()
# Out:
#        CustomerID    JoinDate   Age  Gender       City         Segment  \
# 10095        4700  2023-06-24  30.0    Male  Hyderabad       Corporate
# 10096        3058  2024-05-03  20.0    Male     Multan     Home Office
# 10097        1186  2022-01-25  42.0    Male     Multan        Consumer
# 10098        3208  2023-03-04  47.0  Female        NaN  Small Business
# 10099        9463  2024-08-08  25.0  Female     Multan        Consumer
#
#       ProductCategory    Income  YearsExperience  WebsiteVisits  ...  \
# 10095         Grocery  100597.0                4             41  ...
# 10096         Grocery   78465.0                0            200  ...
# 10097           Books  129940.0               22            153  ...
# 10098     Electronics  135183.0               24            154  ...
# 10099        Clothing  103425.0                2             40  ...
#
#        AvgOrderValue  AnnualSpending  DiscountPercent  EmailOpens  \
# ...

# %% [markdown]
# # Step 5: shape:
#            => used to know about the  number of rows and columns.

# %%
df.shape
# Out:
# (10100, 21)

# %% [markdown]
# # Step 6: columns:
#            => to know columns

# %%
df.columns
# Out:
# Index(['CustomerID', 'JoinDate', 'Age', 'Gender', 'City', 'Segment',
#        'ProductCategory', 'Income', 'YearsExperience', 'WebsiteVisits',
#        'Purchases', 'AvgOrderValue', 'AnnualSpending', 'DiscountPercent',
#        'EmailOpens', 'TimeOnSiteMin', 'SatisfactionScore', 'CreditScore',
#        'HasSubscription', 'ReturnedItems', 'Target_Churn'],
#       dtype='str')

# %% [markdown]
# # Step 7: info()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         10100 non-null  int64
#  1   JoinDate           10100 non-null  str
#  2   Age                9898 non-null   float64
#  3   Gender             10100 non-null  str
#  4   City               9898 non-null   str
#  5   Segment            10100 non-null  str
#  6   ProductCategory    10100 non-null  str
#  7   Income             9898 non-null   float64
#  8   YearsExperience    10100 non-null  int64
#  9   WebsiteVisits      10100 non-null  int64
#  10  Purchases          10100 non-null  int64
#  11  AvgOrderValue      10100 non-null  float64
#  12  AnnualSpending     9898 non-null   float64
#  13  DiscountPercent    10100 non-null  float64
#  14  EmailOpens         10100 non-null  int64
#  15  TimeOnSiteMin      10100 non-null  float64
# ...

# %% [markdown]
# # Step 8: describe().
#            => describe() function is used for statistical information.

# %%
df.describe()
# Out:
#          CustomerID          Age         Income  YearsExperience  \
# count  10100.000000  9898.000000    9898.000000     10100.000000
# mean    4999.962277    44.013437   80715.685088        22.265743
# std     2886.828406    15.266906   34396.999950        15.098602
# min        1.000000    18.000000   15000.000000         0.000000
# 25%     2498.750000    31.000000   56195.250000         9.000000
# 50%     4998.500000    44.000000   80902.000000        22.000000
# 75%     7501.250000    57.000000  104430.000000        35.000000
# max    10000.000000    70.000000  209132.000000        52.000000
#
#        WebsiteVisits     Purchases  AvgOrderValue  AnnualSpending  \
# count   10100.000000  10100.000000   10100.000000    9.898000e+03
# mean      175.994752     19.806634    5256.314352    4.121837e+04
# std       100.683839     11.570778   12036.068439    3.931872e+04
# min         1.000000      0.000000      33.670000    1.304060e+03
# ...

# %% [markdown]
# # Step 9: isna().
#           => isna() function is used for checking missing value.

# %%
df.isna().sum()
# Out:
# CustomerID             0
# JoinDate               0
# Age                  202
# Gender                 0
# City                 202
# Segment                0
# ProductCategory        0
# Income               202
# YearsExperience        0
# WebsiteVisits          0
# Purchases              0
# AvgOrderValue          0
# AnnualSpending       202
# DiscountPercent        0
# EmailOpens             0
# TimeOnSiteMin          0
# SatisfactionScore    202
# CreditScore          202
# HasSubscription        0
# ReturnedItems          0
# Target_Churn           0
# dtype: int64

# %% [markdown]
# # Step 10: fillna().
#             => fillna() is used for filling missing value.

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['City']=df['City'].fillna(df['City'].mode()[0])
df['Income']=df['Income'].fillna(df['Income'].median())
df['AnnualSpending']=df['AnnualSpending'].fillna(df['AnnualSpending'].median())
df['SatisfactionScore']=df['SatisfactionScore'].fillna(df['SatisfactionScore'].median())
df['CreditScore']=df['CreditScore'].fillna(df['CreditScore'].median())

# %%
df
# Out:
#        CustomerID    JoinDate   Age  Gender        City         Segment  \
# 0               1  2022-04-17  21.0    Male   Islamabad     Home Office
# 1               2  2022-10-19  28.0    Male     Karachi     Home Office
# 2               3  2025-08-16  48.0   Other  Faisalabad  Small Business
# 3               4  2024-07-24  50.0  Female      Multan        Consumer
# 4               5  2025-07-14  58.0   Other    Peshawar  Small Business
# ...           ...         ...   ...     ...         ...             ...
# 10095        4700  2023-06-24  30.0    Male   Hyderabad       Corporate
# 10096        3058  2024-05-03  20.0    Male      Multan     Home Office
# 10097        1186  2022-01-25  42.0    Male      Multan        Consumer
# 10098        3208  2023-03-04  47.0  Female      Multan  Small Business
# 10099        9463  2024-08-08  25.0  Female      Multan        Consumer
#
#       ProductCategory    Income  YearsExperience  WebsiteVisits  ...  \
# ...

# %%
df.isna().sum()
# Out:
# CustomerID           0
# JoinDate             0
# Age                  0
# Gender               0
# City                 0
# Segment              0
# ProductCategory      0
# Income               0
# YearsExperience      0
# WebsiteVisits        0
# Purchases            0
# AvgOrderValue        0
# AnnualSpending       0
# DiscountPercent      0
# EmailOpens           0
# TimeOnSiteMin        0
# SatisfactionScore    0
# CreditScore          0
# HasSubscription      0
# ReturnedItems        0
# Target_Churn         0
# dtype: int64

# %% [markdown]
# # Step 10: duplicated().
#              => used for checking of duplicated rows

# %%
df.duplicated().sum()
# Out:
# np.int64(76)

# %% [markdown]
# # Step 11:
#        => droping of duplicated rows and columns

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Step 12: dtypes.
#                => to know about data types

# %%
df.dtypes
# Out:
# CustomerID             int64
# JoinDate                 str
# Age                  float64
# Gender                   str
# City                     str
# Segment                  str
# ProductCategory          str
# Income               float64
# YearsExperience        int64
# WebsiteVisits          int64
# Purchases              int64
# AvgOrderValue        float64
# AnnualSpending       float64
# DiscountPercent      float64
# EmailOpens             int64
# TimeOnSiteMin        float64
# SatisfactionScore    float64
# CreditScore          float64
# HasSubscription        int64
# ReturnedItems          int64
# Target_Churn           int64
# dtype: object

# %% [markdown]
# # Step 13:Selecting One Column.

# %%
df['Age']
# Out:
# 0        21.0
# 1        28.0
# 2        48.0
# 3        50.0
# 4        58.0
#          ...
# 10082    26.0
# 10085    55.0
# 10091    19.0
# 10093    19.0
# 10098    47.0
# Name: Age, Length: 10024, dtype: float64

# %% [markdown]
# # Step 14: Selecting more than one Columns

# %%
df[["Age","Income"]]
# Out:
#         Age    Income
# 0      21.0   73359.0
# 1      28.0  117472.0
# 2      48.0  111405.0
# 3      50.0  137462.0
# 4      58.0   31262.0
# ...     ...       ...
# 10082  26.0   80902.0
# 10085  55.0  148056.0
# 10091  19.0   80313.0
# 10093  19.0  147744.0
# 10098  47.0  135183.0
#
# [10024 rows x 2 columns]

# %% [markdown]
# # Step 15:Filter Rows.

# %%
df[df["Income"] > 100000]
# Out:
#        CustomerID    JoinDate   Age  Gender        City         Segment  \
# 1               2  2022-10-19  28.0    Male     Karachi     Home Office
# 2               3  2025-08-16  48.0   Other  Faisalabad  Small Business
# 3               4  2024-07-24  50.0  Female      Multan        Consumer
# 7               8  2022-10-27  44.0   Other      Quetta  Small Business
# 10             11  2025-01-06  50.0    Male   Islamabad  Small Business
# ...           ...         ...   ...     ...         ...             ...
# 10067        5195  2022-07-03  68.0   Other  Faisalabad  Small Business
# 10072        5288  2025-12-09  49.0    Male     Karachi       Corporate
# 10085        2117  2025-03-12  55.0    Male      Multan        Consumer
# 10093         626  2024-12-04  19.0    Male    Peshawar     Home Office
# 10098        3208  2023-03-04  47.0  Female      Multan  Small Business
#
#       ProductCategory    Income  YearsExperience  WebsiteVisits  ...  \
# ...

# %% [markdown]
# # Step 16:Multiple conditions.

# %%
df[(df["Age"] > 30) & (df["Income"] > 100000)]
# Out:
#        CustomerID    JoinDate   Age  Gender        City         Segment  \
# 2               3  2025-08-16  48.0   Other  Faisalabad  Small Business
# 3               4  2024-07-24  50.0  Female      Multan        Consumer
# 7               8  2022-10-27  44.0   Other      Quetta  Small Business
# 10             11  2025-01-06  50.0    Male   Islamabad  Small Business
# 15             16  2022-01-29  52.0  Female  Faisalabad       Corporate
# ...           ...         ...   ...     ...         ...             ...
# 10066        6392  2022-06-20  53.0    Male      Multan  Small Business
# 10067        5195  2022-07-03  68.0   Other  Faisalabad  Small Business
# 10072        5288  2025-12-09  49.0    Male     Karachi       Corporate
# 10085        2117  2025-03-12  55.0    Male      Multan        Consumer
# 10098        3208  2023-03-04  47.0  Female      Multan  Small Business
#
#       ProductCategory    Income  YearsExperience  WebsiteVisits  ...  \
# ...

# %% [markdown]
# # Step 17: Count Categories.

# %%
df["City"].value_counts()
# Out:
# City
# Multan        1472
# Lahore        1265
# Peshawar      1233
# Islamabad     1230
# Quetta        1220
# Karachi       1205
# Faisalabad    1204
# Hyderabad     1195
# Name: count, dtype: int64

# %% [markdown]
# # Step 18: Group Data

# %%
df.groupby("City")["AnnualSpending"].mean()
# Out:
# City
# Faisalabad    42254.587957
# Hyderabad     40462.639431
# Islamabad     38995.897382
# Karachi       41072.702697
# Lahore        41688.040292
# Multan        42860.696250
# Peshawar      40523.180568
# Quetta        40627.902164
# Name: AnnualSpending, dtype: float64

# %% [markdown]
# # Step 19: Correlation.

# %%
df.corr(numeric_only=True)
# Out:
#                    CustomerID       Age    Income  YearsExperience  \
# CustomerID           1.000000 -0.001342 -0.008748        -0.002677
# Age                 -0.001342  1.000000 -0.020805         0.976455
# Income              -0.008748 -0.020805  1.000000        -0.022280
# YearsExperience     -0.002677  0.976455 -0.022280         1.000000
# WebsiteVisits        0.010428 -0.011702 -0.005443        -0.011975
# Purchases           -0.003472 -0.006722  0.022619        -0.009373
# AvgOrderValue        0.000152 -0.003637  0.171211        -0.005277
# AnnualSpending      -0.000050 -0.014783  0.438041        -0.016032
# DiscountPercent     -0.013227  0.003058 -0.007087         0.002320
# EmailOpens           0.014836 -0.006877 -0.007103        -0.007024
# TimeOnSiteMin       -0.007263 -0.003657  0.007136        -0.001589
# SatisfactionScore    0.015022  0.005177  0.000153         0.001480
# CreditScore         -0.006840  0.438947  0.697761         0.448043
# ...

# %% [markdown]
# # Step 20:
#         => Saving clean dataset

# %%
df.to_csv("Cleand_ml_dataset", index=False)
